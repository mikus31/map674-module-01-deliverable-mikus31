# %%
greeting = "hello deliverable"
print(greeting)
# Out:
# hello deliverable

# %%
import pandas

# %%
import django
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-5fa2257f2ea7> in <module>()
# ----> 1 import django
#
# ModuleNotFoundError: No module named 'django'

# %%
import twisted

# %%
twisted.test()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-5fcd85dd38e1> in <module>()
# ----> 1 twisted.test()
#
# AttributeError: module 'twisted' has no attribute 'test'

# %%
pandas.test()
# Out:
# running: pytest --skip-slow --skip-network C:\Users\mmcneil\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas
# ============================= test session starts =============================
# platform win32 -- Python 3.7.0, pytest-3.8.0, py-1.6.0, pluggy-0.7.1
# rootdir: h:\SCHOOL\KENTUCKY\MAP674\map674-module-01-mikus31\deliverable-01, inifile:
# plugins: remotedata-0.3.0, openfiles-0.3.0, doctestplus-0.1.3, arraydiff-0.2
# collected 26759 items / 2 skipped
#
# pandas\tests\test_algos.py ............................................. [  0%]
# .............X.....................................................      [  0%]
# pandas\tests\test_base.py .............................................. [  0%]
# ........................................................................ [  0%]
# ........................................................................ [  1%]
# ........x                                                                [  1%]
# ...
